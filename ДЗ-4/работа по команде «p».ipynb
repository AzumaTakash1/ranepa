# %%
documents = [
    {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
    {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
    {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]
 
directories = {
    '1': ['2207 876234', '11-2'],
    '2': ['10006'],
    '3': []
}
 
def get_owner_by_document_number(doc_number):
    for doc in documents:
        if doc["number"] == doc_number:
            return doc["name"]
    return None
def handle_p_command():
    doc_number = input("Введите номер документа:").strip()
    owner = get_owner_by_document_number(doc_number)
 
    if owner: print(f"Владелец документа: {owner}")
    else: print("Документ с таким номером не найден")
 
def main():
    print("Добро пожаловать в систему учета документов")
    print("Доступные комманды:")
    print("p - найти владельца документа")
    print("q - выход")
 
    while True:
        command = input("\nВведите команду:").strip().lower()
 
        if command == "q":
            print("Выход из программы. До свидания!")
            break
        elif command == "p":
            handle_p_command()
        else:
            print("Неизвестная комманда. Попробуйте снова.")
 
if __name__ == "__main__":
    main()
# Out:
# Добро пожаловать в систему учета документов
# Доступные комманды:
# p - найти владельца документа
# q - выход
#
# Введите команду:p
# Введите номер документа:11-2
# Владелец документа: Геннадий Покемонов
